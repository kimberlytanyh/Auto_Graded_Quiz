# %% [markdown]
# # Assignment 5

# %% [markdown]
# ### Method 1 (Seems to satisfy requirements the best)

# %%
score = open('score_record.txt', 'w')

def quizv3():
    print("Please key in your name before beginning the quiz.\n")
    name = input("Name: ")
    total_score= 0
    answer_key = open('quiz_answer.txt', 'r')
    
    #Question 1
    print("\nChoose the best answer for the following questions and input the character representing your answer in the prompt below.\n\n")
    print("Question 1: When using loops for repetition structures, when should you use the while loop?\n\n")
    print("A. When you need to use the if statement.\n")
    print("B. If you don't know how many times the loop will/should be executed.\n")
    print("C. If you know how many times the loop will/should be executed.\n")
    correctans = answer_key.readline().rstrip()
    def comparison():
        answer = input("Please enter your answer choice: ")
        if correctans == answer:
            print("Correct\n\n")
            value = True
            return value
        else:
            print("Incorrect\n\n")
    
    if comparison() == True:
        total_score += 10
        
        
    #Question 2
    print("Question 2: When should you use elif?\n\n")
    print("A. When extending if/else statements for additional scenarios.\n")
    print("B. After 'else' has been used.\n")
    print("C. Never.\n")
    correctans = answer_key.readline().rstrip()
    if comparison() == True:
        total_score += 10
    
    #Question 3
    print("Question 3: Which of the following is NOT one of the 3 main data types?\n\n")
    print("A. Strings\n\nB. Fractions\n\nC. Integers\n\nD. Floats\n")
    correctans = answer_key.readline().rstrip()
    if comparison() == True:
        total_score += 10
    
    #Question 4
    print("Question 4: What are floats?\n\n")
    print("A. Whole numbers\n\nB. Numbers with decimal places\n\nC. Infinite numbers\n")
    correctans = answer_key.readline().rstrip()
    if comparison() == True:
        total_score += 10
    
    #Question 5
    print("Question 5: What is \ called in Python?\n\n")
    print("A. Seperator\n\nB. Backslash\n\nC. Escape character\n")
    correctans = answer_key.readline().rstrip()
    if comparison() == True:
        total_score += 10
    
    #Question 6
    print("Question 6: Which of the following is NOT one of the relational operators used to test Boolean expressions?\n\n")
    print("A. =\n\nB. >=\n\nC. !=\n\nD. >\n")
    correctans = answer_key.readline().rstrip()
    if comparison() == True:
        total_score += 10  
    
    #Question 7
    print("Question 7: Which of the following is NOT a logical operator in Python?\n\n")
    print("A. and\n\nB. or\n\nC. not\n\nD. if\n")
    correctans = answer_key.readline().rstrip()
    if comparison() == True:
        total_score += 10
    
    
    #Question 8
    print("Question 8: The condition-controlled loop uses 'for'.\n\n")
    print("A. True\n\nB. False\n")
    correctans = answer_key.readline().rstrip()
    if comparison() == True:
        total_score += 10
    
    
    #Question 9
    print("Question 9: Which of the following is NOT true of nested loops.\n\n")
    print("A. An inner loop goes through all of its iterations for each iteration of an outer loop.\n")
    print("B. To get the total number of iterations of nested loops, multiply the number of iterations of all loops.\n")
    print("C. Outer loops complete their iterations faster than inner loops.\n")
    correctans = answer_key.readline().rstrip()
    if comparison() == True:
        total_score += 10
    
    #Question 10
    print("Question 10: Local variables can be accessed by statements outside the function.\n\n")
    print("A. True\n\nB. False\n")
    correctans = answer_key.readline().rstrip()
    if comparison() == True:
        total_score += 10
    
    if total_score >= 95 and total_score<= 100:
            grade = str("A+")
    elif total_score >= 90 and total_score <= 94:
            grade = str("A")
    elif total_score >= 85 and total_score <= 89:
        grade = str("B+")
    elif total_score >= 80 and total_score <= 84:
        grade = str("B")
    elif total_score >= 75 and total_score <= 79:
        grade = str("C+")
    elif total_score >= 70 and total_score <= 74:
        grade = str("C")
    elif total_score >= 65 and total_score <= 69:
        grade = str("D+")
    elif total_score >= 60 and total_score <= 64:
        grade = str("D")
    elif total_score >= 0 and total_score<= 59:
        grade = str("F")
        
    score = open('score_record.txt','a')
    score.write("Student: "+(name)+ "\n")
    score.write("Grade: " +(grade)+ "\n\n")
    score.close()    
    print("\nYour grade: " + grade + "\nYour grade has been recorded.")
    

quizv3()
# Out:
# Please key in your name before beginning the quiz.
#
# Name: Kim
#
# Choose the best answer for the following questions and input the character representing your answer in the prompt below.
#
#
# Question 1: When using loops for repetition structures, when should you use the while loop?
#
#
# A. When you need to use the if statement.
#
# B. If you don't know how many times the loop will/should be executed.
#
# C. If you know how many times the loop will/should be executed.
#
# Please enter your answer choice: B
# Correct
#
#
# Question 2: When should you use elif?
#
#
# A. When extending if/else statements for additional scenarios.
#
# B. After 'else' has been used.
#
# C. Never.
#
# Please enter your answer choice: A
# Correct
#
#
# Question 3: Which of the following is NOT one of the 3 main data types?
#
#
# A. Strings
#
# B. Fractions
#
# C. Integers
#
# D. Floats
#
# Please enter your answer choice: B
# Correct
#
#
# Question 4: What are floats?
#
#
# A. Whole numbers
#
# ...

# %%
quizv3()
# Out:
# Please key in your name before beginning the quiz.
#
# Name: Kimberly
#
# Choose the best answer for the following questions and input the character representing your answer in the prompt below.
#
#
# Question 1: When using loops for repetition structures, when should you use the while loop?
#
#
# A. When you need to use the if statement.
#
# B. If you don't know how many times the loop will/should be executed.
#
# C. If you know how many times the loop will/should be executed.
#
# Please enter your answer choice: B
# Correct
#
#
# Question 2: When should you use elif?
#
#
# A. When extending if/else statements for additional scenarios.
#
# B. After 'else' has been used.
#
# C. Never.
#
# Please enter your answer choice: B
# Incorrect
#
#
# Question 3: Which of the following is NOT one of the 3 main data types?
#
#
# A. Strings
#
# B. Fractions
#
# C. Integers
#
# D. Floats
#
# Please enter your answer choice: B
# Correct
#
#
# Question 4: What are floats?
#
#
# A. Whole numbers
#
# ...

# %% [markdown]
# ### OR Method 2 (Loops, more inconvenient for test taker with scrolling but less code)

# %%
# Putting the quiz questions into a function to make it easier for the actual programming of the quiz 
# (Backgrond work).

# %%
def quiz_qn():
    print("\nChoose the best answer for the following questions and input the character representing your answer in the prompt below.\n\n")
    print("Question 1: When using loops for repetition structures, when should you use the while loop?\n\n")
    print("A. When you need to use the if statement.\n")
    print("B. If you don't know how many times the loop will/should be executed.\n")
    print("C. If you know how many times the loop will/should be executed.\n\n")
    
    print("Question 2: When should you use elif?\n\n")
    print("A. When extending if/else statements for additional scenarios.\n")
    print("B. After 'else' has been used.\n")
    print("C. Never.\n\n")
    
    print("Question 3: Which of the following is NOT one of the 3 main data types?\n\n")
    print("A. Strings\n\nB. Fractions\n\nC. Integers\n\nD. Floats\n\n")
    
    print("Question 4: What are floats?\n\n")
    print("A. Whole numbers\n\nB. Numbers with decimal places\n\nC. Infinite numbers\n\n")
    
    print("Question 5: What is \ called in Python?\n\n")
    print("A. Seperator\n\nB. Backslash\n\nC. Escape character\n\n")
    
    print("Question 6: Which of the following is NOT one of the relational operators used to test Boolean expressions?\n\n")
    print("A. =\n\nB. >=\n\nC. !=\n\nD. >\n\n")
    
    print("Question 7: Which of the following is NOT a logical operator in Python?\n\n")
    print("A. and\n\nB. or\n\nC. not\n\nD. if\n\n")
    
    print("Question 8: The condition-controlled loop uses 'for'.\n\n")
    print("A. True\n\nB. False\n\n")
    
    print("Question 9: Which of the following is NOT true of nested loops.\n\n")
    print("A. An inner loop goes through all of its iterations for each iteration of an outer loop.\n")
    print("B. To get the total number of iterations of nested loops, multiply the number of iterations of all loops.\n")
    print("C. Outer loops complete their iterations faster than inner loops.\n\n")
    
    print("Question 10: Local variables can be accessed by statements outside the function.\n\n")
    print("A. True\n\nB. False\n\n")

# %%
# Quiz Part

# %%
score = open('score_record.txt', 'w')

def quiz():
    print("Please key in your name before beginning the quiz.\n")
    name = input("Name: ")
    quiz_qn()
    total_score= 0
    answer_key = open('quiz_answer.txt', 'r')
    for question in range (1,11):
        answer = input("Your answer for Question #" + str(question) + ": ")
        correct_ans = answer_key.readline()
        correct_answer = correct_ans.rstrip('\n')
        if answer==correct_answer:
            total_score += 10
            print("Correct.")
        else:
            print("Incorrect.")
    if total_score >= 95 and total_score<= 100:
            grade = str("A+")
    elif total_score >= 90 and total_score <= 94:
            grade = str("A")
    elif total_score >= 85 and total_score <= 89:
        grade = str("B+")
    elif total_score >= 80 and total_score <= 84:
        grade = str("B")
    elif total_score >= 75 and total_score <= 79:
        grade = str("C+")
    elif total_score >= 70 and total_score <= 74:
        grade = str("C")
    elif total_score >= 65 and total_score <= 69:
        grade = str("D+")
    elif total_score >= 60 and total_score <= 64:
        grade = str("D")
    elif total_score >= 0 and total_score<= 59:
        grade = str("F")
        
    score = open('score_record.txt','a')
    score.write("Student: "+(name)+ "\n")
    score.write("Grade: " +(grade)+ "\n\n")
    score.close()    
    def response():
        message = print("\nYour grade: " + grade + "\nYour grade has been recorded.")
        return message
    response()

quiz()

# %% [markdown]
# #### OR
#
# #### Method 3 (Tedious, longer, repetitive way) (For self-note to remember methods/code I explored)

# %%
score = open('score_record.txt', 'w')

def quizv2():
    print("Please key in your name before beginning the quiz.\n")
    name = input("Name: ")
    total_score= 0
    answer_key = open('quiz_answer.txt', 'r')
    
    #Question 1
    print("\nChoose the best answer for the following questions and input the character representing your answer in the prompt below.\n\n")
    print("Question 1: When using loops for repetition structures, when should you use the while loop?\n\n")
    print("A. When you need to use the if statement.\n")
    print("B. If you don't know how many times the loop will/should be executed.\n")
    print("C. If you know how many times the loop will/should be executed.\n\n")
    answer = input("Enter your answer choice: ")
    line = answer_key.readline()
    line = line.rstrip('\n')
    if line == answer:
        print("Correct\n\n")
        total_score += 10
    else:
        print("Incorrect\n\n")  
        
    #Question 2
    print("Question 2: When should you use elif?\n\n")
    print("A. When extending if/else statements for additional scenarios.\n")
    print("B. After 'else' has been used.\n")
    print("C. Never.\n\n")
    answer = input("Enter your answer choice: ")
    line = answer_key.readline()
    line = line.rstrip('\n')
    if line == answer:                                
        print("Correct\n\n")
        total_score += 10
    else:
        print("Incorrect\n\n")  
    
    #Question 3
    print("Question 3: Which of the following is NOT one of the 3 main data types?\n\n")
    print("A. Strings\n\nB. Fractions\n\nC. Integers\n\nD. Floats\n\n")
    answer = input("Enter your answer choice: ")
    line = answer_key.readline()
    line = line.rstrip('\n')
    if line == answer:                    
        print("Correct\n\n")
        total_score += 10
    else:
        print("Incorrect\n\n")  
    
    #Question 4
    print("Question 4: What are floats?\n\n")
    print("A. Whole numbers\n\nB. Numbers with decimal places\n\nC. Infinite numbers\n\n")
    answer = input("Enter your answer choice: ")
    line = answer_key.readline()
    line = line.rstrip('\n')
    if line == answer:
        print("Correct\n\n")                  
        total_score += 10
    else:
        print("Incorrect\n\n")  
    
    #Question 5
    print("Question 5: What is \ called in Python?\n\n")
    print("A. Seperator\n\nB. Backslash\n\nC. Escape character\n\n")
    answer = input("Enter your answer choice: ")
    line = answer_key.readline()
    line = line.rstrip('\n')
    if line == answer:
        print("Correct\n\n")
        total_score += 10
    else:
        print("Incorrect\n\n")  
    
    #Question 6
    print("Question 6: Which of the following is NOT one of the relational operators used to test Boolean expressions?\n\n")
    print("A. =\n\nB. >=\n\nC. !=\n\nD. >\n\n")
    answer = input("Enter your answer choice: ")
    line = answer_key.readline()
    line = line.rstrip('\n')
    if line == answer:
        print("Correct\n\n")
        total_score += 10
    else:
        print("Incorrect\n\n")   
    
    #Question 7
    print("Question 7: Which of the following is NOT a logical operator in Python?\n\n")
    print("A. and\n\nB. or\n\nC. not\n\nD. if\n\n")
    answer = input("Enter your answer choice: ")
    line = answer_key.readline()
    line = line.rstrip('\n')
    if line == answer:
        print("Correct\n\n")
        total_score += 10
    else:
        print("Incorrect\n\n")  
    
    #Question 8
    print("Question 8: The condition-controlled loop uses 'for'.\n\n")
    print("A. True\n\nB. False\n\n")
    answer = input("Enter your answer choice: ")
    line = answer_key.readline()
    line = line.rstrip('\n')
    if line == answer:
        print("Correct\n\n")
        total_score += 10
    else:
        print("Incorrect\n\n")  
    
    #Question 9
    print("Question 9: Which of the following is NOT true of nested loops.\n\n")
    print("A. An inner loop goes through all of its iterations for each iteration of an outer loop.\n")
    print("B. To get the total number of iterations of nested loops, multiply the number of iterations of all loops.\n")
    print("C. Outer loops complete their iterations faster than inner loops.\n\n")
    answer = input("Enter your answer choice: ")
    line = answer_key.readline()
    line = line.rstrip('\n')
    if line == answer:
        print("Correct\n\n")
        total_score += 10
    else:
        print("Incorrect\n\n")  
    
    #Question 10
    print("Question 10: Local variables can be accessed by statements outside the function.\n\n")
    print("A. True\n\nB. False\n\n")
    answer = input("Enter your answer choice: ")
    line = answer_key.readline()
    line = line.rstrip('\n')
    if line == answer:
        print("Correct\n\n")
        total_score += 10
    else:
        print("Incorrect\n\n")   
    
    if total_score >= 95 and total_score<= 100:
            grade = str("A+")
    elif total_score >= 90 and total_score <= 94:
            grade = str("A")
    elif total_score >= 85 and total_score <= 89:
        grade = str("B+")
    elif total_score >= 80 and total_score <= 84:
        grade = str("B")
    elif total_score >= 75 and total_score <= 79:
        grade = str("C+")
    elif total_score >= 70 and total_score <= 74:
        grade = str("C")
    elif total_score >= 65 and total_score <= 69:
        grade = str("D+")
    elif total_score >= 60 and total_score <= 64:
        grade = str("D")
    elif total_score >= 0 and total_score<= 59:
        grade = str("F")
        
    score = open('score_record.txt','a')
    score.write("Student: "+(name)+ "\n")
    score.write("Grade: " +(grade)+ "\n\n")
    score.close()    
    def response():
        message = print("\nYour grade: " + grade + "\nYour grade has been recorded.")
        return message
    response()

quizv2()
